# %%
#@title #Importing libraries & uploading csv file
#Importing libraries & uploading csv file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
#@title #Extracting individual CSVs from main CSV
#Importing libraries & uploading csv file

# %%
demographic_ind = pd.read_csv("/content/drive/MyDrive/Demographic_Indicators_Medium.csv") 
demographic_ind.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID LocTypeName  ParentID Location  VarID Variant  Time  TPopulation1Jan  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime      Births  Births1519     CBR     TFR     NRR     MAC    SRB     Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths        Q5     Q0040  Q0040Male  Q0040Female     Q0060  Q0060Male  Q0060Female     Q1550  Q1550Male  Q1550Female     Q1560  Q1560Male  Q1560Female  NetMigrations  CNMR
# ...

# %%
demographic_ind = demographic_ind.drop(['SortOrder','LocID','Notes','ISO3_code','ISO2_code','SDMX_code','ParentID','VarID','Variant','TPopulation1Jan','Q5','Q0040',
                                        'Q0040Male','Q0040Female','Q0060','Q0060Male','Q0060Female','Q1550','Q1550Male','Q1550Female','Q1560','Q1560Male',
                                        'Q1560Female','CNMR'], axis = 1)

# %%
demographic_ind.head()
# Out:
#    LocTypeID LocTypeName Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime      Births  Births1519     CBR     TFR     NRR     MAC    SRB     Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
data_country_specific = demographic_ind[demographic_ind['LocTypeName'] == 'Country/Area']
data_country_specific = data_country_specific.reset_index(drop=True)
data_country_specific.head()
# Out:
#    LocTypeID   LocTypeName Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime   Births  Births1519     CBR     TFR     NRR     MAC    SRB  Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
data_country_specific.shape
# Out:
# (36024, 43)

# %%
data_country_specific.to_csv('/content/drive/MyDrive/DSCI544_Data/data_country_specific.csv')

# %%
data_Subregion_specific = demographic_ind[demographic_ind['LocTypeName'] == 'Subregion']
data_Subregion_specific = data_Subregion_specific.reset_index(drop=True)
data_Subregion_specific.head()
# Out:
#    LocTypeID LocTypeName        Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime    Births  Births1519     CBR     TFR     NRR     MAC    SRB    Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
data_Subregion_specific.shape
# Out:
# (3192, 43)

# %%
data_Subregion_specific.to_csv('/content/drive/MyDrive/DSCI544_Data/data_Subregion_specific.csv')

# %%
data_SDG_region_specific = demographic_ind[demographic_ind['LocTypeName'] == 'SDG region']
data_SDG_region_specific = data_SDG_region_specific.reset_index(drop=True)
data_SDG_region_specific.head()
# Out:
#    LocTypeID LocTypeName            Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime    Births  Births1519     CBR     TFR     NRR     MAC    SRB    Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
data_SDG_region_specific.shape
# Out:
# (1216, 43)

# %%
data_SDG_region_specific.to_csv('/content/drive/MyDrive/DSCI544_Data/data_SDG_region_specific.csv')

# %%
data_Development_group_specific = demographic_ind[demographic_ind['LocTypeName'] == 'Development group']
data_Development_group_specific = data_Development_group_specific.reset_index(drop=True)
data_Development_group_specific.head()
# Out:
#    LocTypeID        LocTypeName                Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime     Births  Births1519     CBR     TFR     NRR     MAC    SRB    Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths      IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
data_Development_group_specific.shape
# Out:
# (1064, 43)

# %%
data_Development_group_specific.to_csv('/content/drive/MyDrive/DSCI544_Data/data_Development_group_specific.csv')

# %%
data_Geographic_region_specific = demographic_ind[demographic_ind['LocTypeName'] == 'Geographic region']
data_Geographic_region_specific = data_Geographic_region_specific.reset_index(drop=True)
data_Geographic_region_specific.head()
# Out:
#    LocTypeID        LocTypeName Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime     Births  Births1519     CBR     TFR     NRR     MAC    SRB    Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
data_Geographic_region_specific.shape
# Out:
# (912, 43)

# %%
data_Geographic_region_specific.to_csv('/content/drive/MyDrive/DSCI544_Data/data_Geographic_region_specific.csv')

# %%
data_Income_group_specific = demographic_ind[demographic_ind['LocTypeName'] == 'Income group']
data_Income_group_specific = data_Income_group_specific.reset_index(drop=True)
data_Income_group_specific.head()
# Out:
#    LocTypeID   LocTypeName               Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime     Births  Births1519     CBR     TFR     NRR     MAC    SRB    Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths      IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
data_Income_group_specific.shape
# Out:
# (912, 43)

# %%
data_Income_group_specific.to_csv('/content/drive/MyDrive/DSCI544_Data/data_Income_group_specific.csv')

# %%
data_overall_world_specific = demographic_ind[demographic_ind['LocTypeName'] == 'World']
data_overall_world_specific = data_overall_world_specific.reset_index(drop=True)
data_overall_world_specific.head()
# Out:
#    LocTypeID LocTypeName Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime      Births  Births1519     CBR     TFR     NRR     MAC    SRB     Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
data_overall_world_specific.shape
# Out:
# (152, 43)

# %%
data_overall_world_specific.to_csv('/content/drive/MyDrive/DSCI544_Data/data_overall_world_specific.csv')

# %%
#@title #Cleaning data and adding additional features from other CSVs
#Importing libraries & uploading csv file

# %%
battle_related_deaths = pd.read_csv("/content/drive/MyDrive/test_data/battle-related-deaths.csv") 
battle_related_deaths.head()
# Out:
#    Entity Code  Year  Deaths in all state-based conflict types
# 0  Africa  NaN  1946                                       0.0
# 1  Africa  NaN  1947                                    9566.0
# 2  Africa  NaN  1948                                       0.0
# 3  Africa  NaN  1949                                       0.0
# 4  Africa  NaN  1950                                       0.0

# %%
import pandas as pd
active_conflicts = pd.read_csv("/content/drive/MyDrive/test_data/active_conflicts.csv")
active_conflicts.head()
# Out:
#    Entity Code  Year  Number of civil conflicts with foreign state intervention  Number of civil conflicts  Number of conflicts between states  Number of colonial or imperial conflicts
# 0  Africa  NaN  1946                                                  0                                  0                                   0                                         0
# 1  Africa  NaN  1947                                                  0                                  0                                   0                                         1
# 2  Africa  NaN  1948                                                  0                                  0                                   0                                         0
# 3  Africa  NaN  1949                                                  0                                  0                                   0                                         0
# ...

# %%
data_Geographic_region_specific = data_Geographic_region_specific[data_Geographic_region_specific['Time'] <= 2020]
data_Geographic_region_specific = data_Geographic_region_specific[data_Geographic_region_specific['Time'] >= 1960]
data_Geographic_region_specific = data_Geographic_region_specific.reset_index(drop=True)
data_Geographic_region_specific.shape
# Out:
# (366, 43)

# %%
data_Geographic_region_specific['Location'].unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'Latin America and the Caribbean',
#        'Northern America', 'Oceania'], dtype=object)

# %%
data_Geographic_region_specific['Location'] = data_Geographic_region_specific['Location'].replace({'Asia': 'Asia & Oceania', 'Oceania': 'Asia & Oceania'})

# %%
data_Geographic_region_specific['Location'].value_counts()
# Out:
# Asia & Oceania                     122
# Africa                              61
# Europe                              61
# Latin America and the Caribbean     61
# Northern America                    61
# Name: Location, dtype: int64

# %%
data_Geographic_region_specific

# %%
data_Geographic_region_specific2 = data_Geographic_region_specific.sort_values(['Location', 'Time'], ascending=[False, True])
data_Geographic_region_specific2 = data_Geographic_region_specific2.reset_index(drop=True)
data_Geographic_region_specific2
# Out:
#      LocTypeID        LocTypeName                         Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime     Births  Births1519     CBR     TFR     NRR     MAC    SRB     Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
battle_related_deaths = battle_related_deaths[battle_related_deaths['Year'] >= 1960]
battle_related_deaths = battle_related_deaths.reset_index(drop=True)
battle_related_deaths.shape
# Out:
# (366, 4)

# %%
active_conflicts = active_conflicts[active_conflicts['Year'] >= 1960]
active_conflicts = active_conflicts.reset_index(drop=True)
active_conflicts.shape
# Out:
# (366, 7)

# %%
battle_related_deaths['Entity'].unique()
# Out:
# array(['Africa', 'Americas', 'Asia & Oceania', 'Europe', 'Middle East',
#        'World'], dtype=object)

# %%
active_conflicts['Entity'].unique()
# Out:
# array(['Africa', 'Americas', 'Asia & Oceania', 'Europe', 'Middle East',
#        'World'], dtype=object)

# %%
battle_related_deaths['Entity'] = battle_related_deaths['Entity'].replace({'Middle East': 'Asia & Oceania', 'Americas': 'Northern America','World': 'Latin America and the Caribbean'})

# %%
battle_related_deaths['Entity'].value_counts()
# Out:
# Asia & Oceania                     122
# Africa                              61
# Northern America                    61
# Europe                              61
# Latin America and the Caribbean     61
# Name: Entity, dtype: int64

# %%
active_conflicts['Entity'] = active_conflicts['Entity'].replace({'Middle East': 'Asia & Oceania', 'Americas': 'Northern America','World': 'Latin America and the Caribbean'})

# %%
active_conflicts['Entity'].value_counts()
# Out:
# Asia & Oceania                     122
# Africa                              61
# Northern America                    61
# Europe                              61
# Latin America and the Caribbean     61
# Name: Entity, dtype: int64

# %%
NorthA = battle_related_deaths[battle_related_deaths['Entity'] == 'Northern America']['Deaths in all state-based conflict types']
list1 = NorthA.tolist()

# %%
list1[:4]
# Out:
# [0.0, 823.5, 400.0, 25.0]

# %%
LatinA = battle_related_deaths[battle_related_deaths['Entity'] == 'Latin America and the Caribbean']['Deaths in all state-based conflict types']
list2 = LatinA.tolist()

# %%
Eur = battle_related_deaths[battle_related_deaths['Entity'] == 'Europe']['Deaths in all state-based conflict types']
list3 = Eur.tolist()

# %%
AOc = battle_related_deaths[battle_related_deaths['Entity'] == 'Asia & Oceania']['Deaths in all state-based conflict types']
list4 = AOc.tolist()

# %%
Afr = battle_related_deaths[battle_related_deaths['Entity'] == 'Africa']['Deaths in all state-based conflict types']
list5 = Afr.tolist()

# %%
fin_list = []
fin_list = list1 + list2 + list3 + list4 + list5
len(fin_list)
# Out:
# 366

# %%
NorthA1 = active_conflicts[active_conflicts['Entity'] == 'Northern America']['Number of civil conflicts with foreign state intervention']
NorthA2 = active_conflicts[active_conflicts['Entity'] == 'Northern America']['Number of civil conflicts']
NorthA3 = active_conflicts[active_conflicts['Entity'] == 'Northern America']['Number of conflicts between states']
NorthA4 = active_conflicts[active_conflicts['Entity'] == 'Northern America']['Number of colonial or imperial conflicts']
list1 = NorthA1.tolist()
list2 = NorthA2.tolist()
list3 = NorthA3.tolist()
list4 = NorthA4.tolist()

# %%
LatinA1 = active_conflicts[active_conflicts['Entity'] == 'Latin America and the Caribbean']['Number of civil conflicts with foreign state intervention']
LatinA2 = active_conflicts[active_conflicts['Entity'] == 'Latin America and the Caribbean']['Number of civil conflicts']
LatinA3 = active_conflicts[active_conflicts['Entity'] == 'Latin America and the Caribbean']['Number of conflicts between states']
LatinA4 = active_conflicts[active_conflicts['Entity'] == 'Latin America and the Caribbean']['Number of colonial or imperial conflicts']
list5 = LatinA1.tolist()
list6 = LatinA2.tolist()
list7 = LatinA3.tolist()
list8 = LatinA4.tolist()

# %%
EurA1 = active_conflicts[active_conflicts['Entity'] == 'Europe']['Number of civil conflicts with foreign state intervention']
EurA2 = active_conflicts[active_conflicts['Entity'] == 'Europe']['Number of civil conflicts']
EurA3 = active_conflicts[active_conflicts['Entity'] == 'Europe']['Number of conflicts between states']
EurA4 = active_conflicts[active_conflicts['Entity'] == 'Europe']['Number of colonial or imperial conflicts']
list9 = EurA1.tolist()
list10 = EurA2.tolist()
list11 = EurA3.tolist()
list12 = EurA4.tolist()

# %%
AocA1 = active_conflicts[active_conflicts['Entity'] == 'Asia & Oceania']['Number of civil conflicts with foreign state intervention']
AocA2 = active_conflicts[active_conflicts['Entity'] == 'Asia & Oceania']['Number of civil conflicts']
AocA3 = active_conflicts[active_conflicts['Entity'] == 'Asia & Oceania']['Number of conflicts between states']
AocA4 = active_conflicts[active_conflicts['Entity'] == 'Asia & Oceania']['Number of colonial or imperial conflicts']
list13 = AocA1.tolist()
list14 = AocA2.tolist()
list15 = AocA3.tolist()
list16 = AocA4.tolist()

# %%
AfrA1 = active_conflicts[active_conflicts['Entity'] == 'Africa']['Number of civil conflicts with foreign state intervention']
AfrA2 = active_conflicts[active_conflicts['Entity'] == 'Africa']['Number of civil conflicts']
AfrA3 = active_conflicts[active_conflicts['Entity'] == 'Africa']['Number of conflicts between states']
AfrA4 = active_conflicts[active_conflicts['Entity'] == 'Africa']['Number of colonial or imperial conflicts']
list17 = AfrA1.tolist()
list18 = AfrA2.tolist()
list19 = AfrA3.tolist()
list20 = AfrA4.tolist()

# %%
fin_list1 = []; fin_list2 = []; fin_list3 = []; fin_list4 = []
fin_list1 = list1 + list5 + list9 + list13 + list17
fin_list2 = list2 + list6 + list10 + list14 + list18
fin_list3 = list3 + list7 + list11 + list15 + list19
fin_list4 = list4 + list8 + list12 + list16 + list20
print(len(fin_list1))
print(len(fin_list2))
print(len(fin_list3))
print(len(fin_list4))
# Out:
# 366
# 366
# 366
# 366

# %%
data_Geographic_region_specific2['War_Deaths'] = fin_list
data_Geographic_region_specific2['Foreign_Invasion_War'] = fin_list1
data_Geographic_region_specific2['Civil_War'] = fin_list2
data_Geographic_region_specific2['Inter_country_War'] = fin_list3
data_Geographic_region_specific2['Imperial_Invasion_War'] = fin_list4

# %%
data_Geographic_region_specific2.head()
# Out:
#    LocTypeID        LocTypeName          Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime    Births  Births1519     CBR     TFR     NRR     MAC    SRB    Deaths  DeathsMale  DeathsFemale    CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths      IMR  LBsurvivingAge1  Under5Deaths  NetMigrations  War_Deaths  Foreign_Invasion_War  Civil_War  Inter_country_War  Imperial_Invasion_War
# ...

# %%
data_Geographic_region_specific2.to_csv('/content/drive/MyDrive/data_Geographic_region_specific.csv')

# %%
data_country_specific.head()
# Out:
#    LocTypeID   LocTypeName Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime   Births  Births1519     CBR     TFR     NRR     MAC    SRB  Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
Unemployment_data = pd.read_csv("/content/drive/MyDrive/test_data/Unemployment_transformed.csv")
Unemployment_data.head()
# Out:
#    Unnamed: 0 Country_Name Country_Code  Year  Unemployment
# 0           0        Aruba          ABW  1960           NaN
# 1           1        Aruba          ABW  1961           NaN
# 2           2        Aruba          ABW  1962           NaN
# 3           3        Aruba          ABW  1963           NaN
# 4           4        Aruba          ABW  1964           NaN

# %%
Unemployment_data = Unemployment_data.drop(['Unnamed: 0','Country_Code'], axis = 1)
Unemployment_data.head()
# Out:
#   Country_Name  Year  Unemployment
# 0        Aruba  1960           NaN
# 1        Aruba  1961           NaN
# 2        Aruba  1962           NaN
# 3        Aruba  1963           NaN
# 4        Aruba  1964           NaN

# %%
GDP_transformed_data = pd.read_csv("/content/drive/MyDrive/test_data/GDP_transformed.csv")
GDP_transformed_data.head()
# Out:
#    Unnamed: 0 Country_Name Country_Code  Year  GDP
# 0           0        Aruba          ABW  1960  NaN
# 1           1        Aruba          ABW  1961  NaN
# 2           2        Aruba          ABW  1962  NaN
# 3           3        Aruba          ABW  1963  NaN
# 4           4        Aruba          ABW  1964  NaN

# %%
GDP_transformed_data = GDP_transformed_data.drop(['Unnamed: 0','Country_Code'], axis = 1)
GDP_transformed_data.head()
# Out:
#   Country_Name  Year  GDP
# 0        Aruba  1960  NaN
# 1        Aruba  1961  NaN
# 2        Aruba  1962  NaN
# 3        Aruba  1963  NaN
# 4        Aruba  1964  NaN

# %%
l1 = list(Unemployment_data['Country_Name'].unique())
l2 = sorted(l1)
l2

# %%
l3 = list(data_country_specific['Location'].unique())
l4 = sorted(l3)
l4

# %%
df = pd.DataFrame({'unemployment': pd.Series(l2), 'country_specific': pd.Series(l4)})

# %%
df
# Out:
#                                           unemployment                    country_specific
# 0                                          Afghanistan                         Afghanistan
# 1                          Africa Eastern and Southern                             Albania
# 2                           Africa Western and Central                             Algeria
# 3                                              Albania                      American Samoa
# 4                                              Algeria                             Andorra
# 5                                       American Samoa                              Angola
# 6                                              Andorra                            Anguilla
# 7                                               Angola                 Antigua and Barbuda
# 8                                  Antigua and Barbuda                           Argentina
# ...

# %%
Unemployment_data['Country_Name'] = Unemployment_data['Country_Name'].replace({'Bahamas, The': 'Bahamas', 'Egypt, Arab Rep.': 'Egypt',
                                                                               'Gambia, The': 'Gambia', 'Iran, Islamic Rep.':'Iran (Islamic Republic of)',
                                                                               'Korea, Rep.':'Republic of Korea', 'Kyrgyz Republic':'Kyrgyzstan', 'Moldova':'Republic of Moldova',
                                                                               'Slovak Republic': 'Slovakia','Tanzania':'United Republic of Tanzania', 'United States':'United States of America',
                                                                               'Venezuela, RB':'Venezuela (Bolivarian Republic of)', 'Yemen, Rep.': 'Yemen'})

# %%
Unemployment_data.shape
# Out:
# (16492, 3)

# %%
values = ['Africa Eastern and Southern', 'Africa Western and Central','Arab World','Caribbean small states','Central Europe and the Baltics','Channel Islands','Early-demographic dividend',
          'East Asia & Pacific', 'East Asia & Pacific (IDA & IBRD countries)', 'East Asia & Pacific (excluding high income)','Euro area','Europe & Central Asia','Europe & Central Asia (IDA & IBRD countries)',
          'Europe & Central Asia (excluding high income)','European Union','Fragile and conflict affected situations','Heavily indebted poor countries (HIPC)', 'High income', 'IBRD only','IDA & IBRD total',
          'IDA blend','IDA only','IDA total', 'North America', 'Not classified', 'OECD members', 'Middle East & North Africa','Middle East & North Africa (IDA & IBRD countries)', 'Middle East & North Africa (excluding high income)',
          'Middle income', 'Low & middle income', 'Low income', 'Lower middle income', 'Least developed countries: UN classification', 'Latin America & the Caribbean (IDA & IBRD countries)', 'Latin America & Caribbean (excluding high income)',
          'Latin America & Caribbean', 'Late-demographic dividend','Other small states', 'Pacific island small states', 'Post-demographic dividend', 'Pre-demographic dividend', 'Small states', 'South Asia', 'South Asia (IDA & IBRD)', 'Sub-Saharan Africa',
          'Sub-Saharan Africa (IDA & IBRD countries)', 'Sub-Saharan Africa (excluding high income)', 'Upper middle income','World','West Bank and Gaza']

Unemployment_data = Unemployment_data[Unemployment_data.Country_Name.isin(values) == False]

# %%
Unemployment_data.shape
# Out:
# (13330, 3)

# %%
GDP_transformed_data['Country_Name'] = GDP_transformed_data['Country_Name'].replace({'Bahamas, The': 'Bahamas', 'Egypt, Arab Rep.': 'Egypt',
                                                                               'Gambia, The': 'Gambia', 'Iran, Islamic Rep.':'Iran (Islamic Republic of)',
                                                                               'Korea, Rep.':'Republic of Korea', 'Kyrgyz Republic':'Kyrgyzstan', 'Moldova':'Republic of Moldova',
                                                                               'Slovak Republic': 'Slovakia','Tanzania':'United Republic of Tanzania', 'United States':'United States of America',
                                                                               'Venezuela, RB':'Venezuela (Bolivarian Republic of)', 'Yemen, Rep.': 'Yemen'})

# %%
GDP_transformed_data.shape
# Out:
# (16492, 3)

# %%
values = ['Africa Eastern and Southern', 'Africa Western and Central','Arab World','Caribbean small states','Central Europe and the Baltics','Channel Islands','Early-demographic dividend',
          'East Asia & Pacific', 'East Asia & Pacific (IDA & IBRD countries)', 'East Asia & Pacific (excluding high income)','Euro area','Europe & Central Asia','Europe & Central Asia (IDA & IBRD countries)',
          'Europe & Central Asia (excluding high income)','European Union','Fragile and conflict affected situations','Heavily indebted poor countries (HIPC)', 'High income', 'IBRD only','IDA & IBRD total',
          'IDA blend','IDA only','IDA total', 'North America', 'Not classified', 'OECD members', 'Middle East & North Africa','Middle East & North Africa (IDA & IBRD countries)', 'Middle East & North Africa (excluding high income)',
          'Middle income', 'Low & middle income', 'Low income', 'Lower middle income', 'Least developed countries: UN classification', 'Latin America & the Caribbean (IDA & IBRD countries)', 'Latin America & Caribbean (excluding high income)',
          'Latin America & Caribbean', 'Late-demographic dividend','Other small states', 'Pacific island small states', 'Post-demographic dividend', 'Pre-demographic dividend', 'Small states', 'South Asia', 'South Asia (IDA & IBRD)', 'Sub-Saharan Africa',
          'Sub-Saharan Africa (IDA & IBRD countries)', 'Sub-Saharan Africa (excluding high income)', 'Upper middle income','World','West Bank and Gaza']

GDP_transformed_data = GDP_transformed_data[GDP_transformed_data.Country_Name.isin(values) == False]

# %%
GDP_transformed_data.shape
# Out:
# (13330, 3)

# %%
data_country_specific['Location'] = data_country_specific['Location'].replace({'Bolivia (Plurinational State of)': 'Bolivia', 'China, Hong Kong SAR': 'Hong Kong SAR, China',
                                                                               'China, Macao SAR': 'Macao SAR, China', "Dem. People's Republic of Korea":"Korea, Dem. People's Rep.",
                                                                               "Côte d'Ivoire":"Cote d'Ivoire", 'Democratic Republic of the Congo':'Congo, Dem. Rep.', 'Congo':'Congo, Rep.',
                                                                               'Kosovo (under UNSC res. 1244)': 'Kosovo','Saint Kitts and Nevis':'St. Kitts and Nevis', 'Saint Lucia':'St. Lucia',
                                                                               'Saint Martin (French part)':'St. Martin (French part)', 'Saint Vincent and the Grenadines': 'St. Vincent and the Grenadines',
                                                                               'Türkiye':'Turkiye', 'United States Virgin Islands':'Virgin Islands (U.S.)','Viet Nam':'Vietnam', "Lao People's Democratic Republic":"Lao PDR"})

# %%
data_country_specific.shape
# Out:
# (36024, 43)

# %%
values = ['Anguilla', 'Bonaire, Sint Eustatius and Saba','China, Taiwan Province of China','Cook Islands','Falkland Islands (Malvinas)','French Guiana','Guadeloupe','Guernsey',
          'Holy See', 'Jersey', 'Martinique', 'Mayotte', 'Montserrat', 'Niue', 'Réunion', 'Saint Barthélemy','Saint Helena','Saint Pierre and Miquelon', 'State of Palestine', 'Tokelau',
          'Wallis and Futuna Islands', 'Western Sahara']

data_country_specific = data_country_specific[data_country_specific.Location.isin(values) == False]

# %%
data_country_specific.shape
# Out:
# (32680, 43)

# %%
data_country_specific = data_country_specific[data_country_specific['Time'] <= 2020]
data_country_specific = data_country_specific[data_country_specific['Time'] >= 1960]
data_country_specific = data_country_specific.reset_index(drop=True)
data_country_specific.shape
# Out:
# (13115, 43)

# %%
Unemployment_data = Unemployment_data[Unemployment_data['Year'] <= 2020]
Unemployment_data = Unemployment_data.reset_index(drop=True)
Unemployment_data.shape
# Out:
# (13115, 3)

# %%
GDP_transformed_data = GDP_transformed_data[GDP_transformed_data['Year'] <= 2020]
GDP_transformed_data = GDP_transformed_data.reset_index(drop=True)
GDP_transformed_data.shape
# Out:
# (13115, 3)

# %%
data_country_specific2 = data_country_specific.sort_values(['Location', 'Time'], ascending=[True, True])
data_country_specific2 = data_country_specific2.reset_index(drop=True)
data_country_specific2
# Out:
#        LocTypeID   LocTypeName     Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime   Births  Births1519     CBR     TFR     NRR     MAC    SRB   Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female     LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations
# ...

# %%
Unemployment_data2 = Unemployment_data.sort_values(['Country_Name', 'Year'], ascending=[True, True])
Unemployment_data2 = Unemployment_data2.reset_index(drop=True)
Unemployment_data2
# Out:
#       Country_Name  Year  Unemployment
# 0      Afghanistan  1960           NaN
# 1      Afghanistan  1961           NaN
# 2      Afghanistan  1962           NaN
# 3      Afghanistan  1963           NaN
# 4      Afghanistan  1964           NaN
# ...            ...   ...           ...
# 13110     Zimbabwe  2016           NaN
# 13111     Zimbabwe  2017           NaN
# 13112     Zimbabwe  2018           NaN
# 13113     Zimbabwe  2019          7.37
# 13114     Zimbabwe  2020           NaN
#
# [13115 rows x 3 columns]

# %%
GDP_transformed_data2 = GDP_transformed_data.sort_values(['Country_Name', 'Year'], ascending=[True, True])
GDP_transformed_data2 = GDP_transformed_data2.reset_index(drop=True)
GDP_transformed_data2
# Out:
#       Country_Name  Year       GDP
# 0      Afghanistan  1960       NaN
# 1      Afghanistan  1961       NaN
# 2      Afghanistan  1962       NaN
# 3      Afghanistan  1963       NaN
# 4      Afghanistan  1964       NaN
# ...            ...   ...       ...
# 13110     Zimbabwe  2016  0.755869
# 13111     Zimbabwe  2017  4.709492
# 13112     Zimbabwe  2018  4.824211
# 13113     Zimbabwe  2019 -6.144236
# 13114     Zimbabwe  2020 -6.248748
#
# [13115 rows x 3 columns]

# %%
l11 = (Unemployment_data2['Unemployment']).to_list()
l11

# %%
l22 = (GDP_transformed_data2['GDP']).to_list()
l22

# %%
data_country_specific2['Unemployment'] = l11
data_country_specific2['GDP'] = l22
data_country_specific2.head()
# Out:
#    LocTypeID   LocTypeName     Location  Time  TPopulation1July  TPopulationMale1July  TPopulationFemale1July  PopDensity  PopSexRatio  MedianAgePop  NatChange  NatChangeRT  PopChange  PopGrowthRate  DoublingTime   Births  Births1519     CBR     TFR     NRR     MAC    SRB   Deaths  DeathsMale  DeathsFemale     CDR      LEx  LExMale  LExFemale     LE15  LE15Male  LE15Female    LE65  LE65Male  LE65Female    LE80  LE80Male  LE80Female  InfantDeaths       IMR  LBsurvivingAge1  Under5Deaths  NetMigrations  Unemployment  GDP
# ...

# %%
data_country_specific2.to_csv('/content/drive/MyDrive/data_country_specific.csv')
